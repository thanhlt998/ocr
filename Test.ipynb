# %%
from clova_text_recognition import predict
from  glob import glob as gl
import cv2
files = gl("Test/3/*")
imgs = [cv2.imread(file, 1) for file in files]
out = predict(imgs)
for i in range(len(out)):
    print(files[i], out[i])
# Out:
# Test/3/5&.jpg 5
# Test/3/Videotex,.jpg Videotex
# Test/3/00085.jpg OO085
# Test/3/0603.jpg 0603
# Test/3/Council of Europe.jpg CounciI of Europe
# Test/3/requested information.jpg requested intomaton
# Test/3/speaker.jpg speaker
# Test/3/entered.jpg enitered
# Test/3/completely.jpg completely
# Test/3/FACULTY OF INFORMATION TECHNOLOGY.jpg 3QULzr9FXk*.d3I0l'TG!N01QQY
# Test/3/The War of the Worlds.png The War of the Worlds
# Test/3/01010.jpg 01010
# Test/3/Round.jpg Round
# Test/3/narrowly.png narrowly
# Test/3/enabling.jpg enabling
# Test/3/above.jpg above
# Test/3/PDFfile.jpg PDFfile
# Test/3/Samsung Software Challenge 2016.jpg Samsung Soitware Challenge 2016
# Test/3/obtain information.jpg obtain information
# Test/3/The speaker.jpg The speaker
# Test/3/Pham Truong So&n&.jpg Pham Truong Son
# Test/3/K.jpg K
# Test/3/Test.jpg Test
# Test/3/0603&.jpg 0603
# Test/3/understand.jpg understand
# Test/3/Military Technical Academy.jpg Military.Technical Academy.
# Test/3/AWARD.jpg AWARD
# ...
